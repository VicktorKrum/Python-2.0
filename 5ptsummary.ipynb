# %% [markdown]
# <a href="https://colab.research.google.com/github/VicktorKrum/Python-2.0/blob/main/5ptsummary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = [27,12,15,14,18,24,42,34,31,29,41,50]

# %%
#manual method

# %%
sorted_data = sorted(data)

# %%
sorted_data
# Out:
# [12, 14, 15, 18, 24, 27, 29, 31, 34, 41, 42, 50]

# %%
minimum=sorted_data[0]

# %%
maximum=sorted_data[-1]

# %%
n=0
for i in data:
  n=n+1
n=n/2
n= int(n)
n
# Out:
# 6

# %%
  median=0
#def med():
  if (n%2) == 0:
    m=n-1
    median = (sorted_data[n]+sorted_data[m])/2

  if (n%2) == 1:
    median = sorted_data[n]
  #return median

# %%
median
# Out:
# 28.0

# %%
lower_half = sorted_data[:n]
upper_half = sorted_data[n:]
print(lower_half, upper_half)
# Out:
# [12, 14, 15, 18, 24, 27] [29, 31, 34, 41, 42, 50]

# %%
lower_half[int((len(lower_half ))/2)]
# Out:
# 18

# %%
if len(lower_half)%2 == 1:
  q1=   lower_half[int((len(lower_half ))/2)]
#lower_half[int(len(lower_half ))/2]
else:
  q1 = (lower_half[int((len(lower_half ))/2)]+lower_half[int((len(lower_half )/2))-1])/2
print(q1)




#lower_half = [4, 2, 29, 6, 8, 5]
# Out:
# 16.5

# %%
if len(upper_half)%2 == 1:
  q3= upper_half[int(len(upper_half ))/2]
else:
  q3 = (upper_half[int(len(upper_half )/2)]+upper_half[int((len(upper_half )/2))-1])/2
q3
# Out:
# 37.5

# %%
print(minimum ,'=minimum')
print(q1, '=Q1')
print(median, '=median')
print(q3 , '=Q3')
print(maximum, '=maximum')
print('Range=', maximum-minimum)
print('IQR=', q3-q1)
# Out:
# 12 =minimum
# 16.5 =Q1
# 28.0 =median
# 37.5 =Q3
# 50 =maximum
# Range= 38
# IQR= 21.0

# %% [markdown]
# ## **USING NUMPY**

# %%
import numpy as np

# %%
min = np.min(data)
max = np.max(data)
Q1 = np.percentile(sorted_data, 25, interpolation = 'linear')
median = np.median(data)
Q3 = np.percentile(data, 75, method='midpoint')

# %%
print("min=", min);print("Q1=",Q1); print(median, '=median'); print('Q3= ',Q3); print(max, '=max')
# Out:
# min= 12
# Q1= 17.25
# 28.0 =median
# Q3=  37.5
# 50 =max
